# %% [markdown]
# Question:
# Create a Jupyter notebook called Top10.ipynb, analyze what the top 10 causes of calls to 311 are in your chosen ZIP code, and calculate how many total incidents of each of these 10 types there have been in the year 2020.
#
# Your answer should be a pandas.Series which you must call top10 (as a Python variable), which should be in descending order by number of incidents, and which contains as its labels the incident type (a string) and as associated values the total number of incidents of this type in 2020.

# %%
import pandas as pd
df = pd.read_csv("311_Service_Requests_2020.csv")
df.head(10)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1    45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2    45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3    45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4    45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 5    45288728  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 6    45289555  01/01/2020 12:00:00 AM  01/02/2020 09:39:33 AM  DOHMH
# 7    45288120  01/01/2020 12:00:00 AM  01/02/2020 09:51:29 AM  DOHMH
# 8    45289558  01/01/2020 12:00:00 AM  01/15/2020 12:00:01 AM  DOHMH
# ...

# %% [markdown]
# Now, we want to sort the table by zip code for 2020 which was selected, 10025 and sort by causes starting with the top causes and moving down. Here we check that date is 2020 and copt the required columns to a new dataframe

# %%
df['year'] = df['Created Date'].str[6:10]
df[df['year']!='2020']
print('The dataframe does not contain any dates beyond 2020. The shortened table with relevant columns is shown below:')
df1 = df[['Complaint Type', 'Incident Zip']].copy()
df1.head(10)
# Out:
# The dataframe does not contain any dates beyond 2020. The shortened table with relevant columns is shown below:
#      Complaint Type  Incident Zip
# 0    Food Poisoning       11229.0
# 1    Food Poisoning       10458.0
# 2    Food Poisoning       11203.0
# 3    Food Poisoning       11214.0
# 4    Food Poisoning       11385.0
# 5    Food Poisoning       11225.0
# 6    Food Poisoning       11421.0
# 7    Food Poisoning       10455.0
# 8    Food Poisoning       11215.0
# 9  Blocked Driveway       11210.0

# %% [markdown]
# We want to take the above smaller dataframe, and create a dataframe with only 10025.0 as the incident zip and with years as 2020.

# %%
df2 = df1[df1.values == 10025.0]
df2
# Out:
#                      Complaint Type  Incident Zip
# 11              Noise - Residential       10025.0
# 141             Noise - Residential       10025.0
# 463             Noise - Residential       10025.0
# 979      For Hire Vehicle Complaint       10025.0
# 1166                 HEAT/HOT WATER       10025.0
# ...                             ...           ...
# 2586233              HEAT/HOT WATER       10025.0
# 2586442         Noise - Residential       10025.0
# 2586758                      Rodent       10025.0
# 2586833         Noise - Residential       10025.0
# 2586908         Noise - Residential       10025.0
#
# [20978 rows x 2 columns]

# %% [markdown]
# Now, we want to take the complaints that are prevalent. We also want to group the complaints together right after. We also group them and create a series for the number of complaints of that type.

# %%
df3 = df2[['Complaint Type']]
df4 = df3.groupby(['Complaint Type']).size()

# %% [markdown]
# We sort the series in descending order and assign the first 10 most complaints to a different variable

# %%
series = df4.sort_values(ascending = False)
top10 = series.head(10)
top10
# Out:
# Complaint Type
# Noise - Residential            2952
# Noise - Street/Sidewalk        2128
# HEAT/HOT WATER                 1885
# Noise                          1131
# Illegal Parking                 792
# Noise - Vehicle                 787
# Non-Emergency Police Matter     773
# Rodent                          691
# Illegal Fireworks               672
# UNSANITARY CONDITION            565
# dtype: int64
